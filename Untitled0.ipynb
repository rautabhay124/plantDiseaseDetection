# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import tensorflow as tf

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.applications.inception_v3 import preprocess_input
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Sequential
import numpy as np
import matplotlib.pyplot as plt
from glob import glob

# %%
IMAGE_SIZE = [400, 400]
train_path = '/content/contentdrive/MyDrive/Agri_project'
valid_path = '/content/contentdrive/MyDrive/test/TEST'

# %%
inception = InceptionV3(input_shape=IMAGE_SIZE + [3], weights='imagenet', include_top=False)
# Out:
# ...
# 87910968/87910968 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
for layer in inception.layers:
  layer.trainable = False #backtrack stop

# %%
folders=glob('/content/drive/MyDrive/Agri_project/*')

# %%
folders
# Out:
# ['/content/drive/MyDrive/Agri_project/cashew_healthy5877',
#  '/content/drive/MyDrive/Agri_project/cashew_leaf miner3466',
#  '/content/drive/MyDrive/Agri_project/cashew_gumosis1714',
#  '/content/drive/MyDrive/Agri_project/cashew_red rust4751',
#  '/content/drive/MyDrive/Agri_project/cashew_anthracnose3102',
#  '/content/drive/MyDrive/Agri_project/cassava_bacterial blight3241',
#  '/content/drive/MyDrive/Agri_project/cassava_healthy',
#  '/content/drive/MyDrive/Agri_project/cassava_brown spot',
#  '/content/drive/MyDrive/Agri_project/cassava_mosaic',
#  '/content/drive/MyDrive/Agri_project/cassava_green mite',
#  '/content/drive/MyDrive/Agri_project/cassava_bacterial blight',
#  '/content/drive/MyDrive/Agri_project/maize_leaf blight',
#  '/content/drive/MyDrive/Agri_project/maize_leaf spot',
#  '/content/drive/MyDrive/Agri_project/maize_healthy',
#  '/content/drive/MyDrive/Agri_project/maize_streak virus',
#  '/content/drive/MyDrive/Agri_project/maize_grasshoper',
# ...

# %%
x=Flatten(name='flatten')(inception.output)

# %%
prediction=Dense(len(folders),activation='softmax')(x)#to connect all output nodes to last layer of hidden layer

# %%
model=Model(inputs=inception.input,outputs=prediction)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_1 (InputLayer)        [(None, 400, 400, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 199, 199, 32)         864       ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 199, 199, 32)         96        ['conv2d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 199, 199, 32)         0         ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 197, 197, 32)         9216      ['activation[0][0]']
#
#  batch_normalization_1 (Bat  (None, 197, 197, 32)         96        ['conv2d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 197, 197, 32)         0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
# ...

# %%
model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen=ImageDataGenerator(rescale=1./255,shear_range=0.2,zoom_range=0.2,horizontal_flip=True)
test_datagen=ImageDataGenerator(rescale=1./255)

# %%
training_set=train_datagen.flow_from_directory('/content/drive/MyDrive/Agri_project',target_size=(400,400),batch_size=16,class_mode='sparse')
# Out:
# Found 93776 images belonging to 23 classes.

# %%
test_set=test_datagen.flow_from_directory('/content/drive/MyDrive/test/TEST',target_size=(400,400),batch_size=16,class_mode='sparse')
# Out:
# Found 24998 images belonging to 22 classes.

# %%
r=model.fit(training_set,
                      validation_data=test_set,
                      epochs=10,
                      steps_per_epoch=len(training_set),
                      validation_steps=len(test_set)
                      )
# Out:
# Epoch 1/10
#    1/5861 [..............................] - ETA: 23:04:07 - loss: 3.4243 - accuracy: 0.0000e+00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-542a1585cf32> in <cell line: 1>()
# ----> 1 r=model.fit(training_set,
#       2                       validation_data=test_set,
#       3                       epochs=10,
#       4                       steps_per_epoch=len(training_set),
#       5                       validation_steps=len(test_set)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ...
